# %% [markdown]
# # 문제 2 코드 연습 노트
#
# AI_LOG는 질문 요약, 여기는 코드 실험용.

# %%
# Q01. 이 문제는 결국 뭘 하라는 거지?
print("RGB -> 밝기 -> 평균 -> 0/1")

# %%
# Q02. RGB가 뭐지?
colors = {"red": (255,0,0), "green": (0,255,0), "blue": (0,0,255)}
for name, rgb in colors.items():
    print(name, rgb)

# %%
# Q03. 왜 RGB는 0부터 255까지 쓰지?
print(2**8)
print(2**8 - 1)

# %%
# Q04. `255,0,0`은 숫자인가 문자열인가?
pixel = "255,0,0"
print(pixel)
print(type(pixel))
print(pixel.split(","))

# %%
# Q05. 검은색하고 흰색은 어떻게 표시하지?
black=(0,0,0)
white=(255,255,255)
print(sum(black)//3)
print(sum(white)//3)

# %%
# Q06. 왜 RGB 세 개를 밝기 하나로 바꾸지?
red=(255,0,0)
gray=(85,85,85)
print(sum(red)//3)
print(sum(gray)//3)

# %%
# Q07. 밝기 공식은 정확히 뭐였지?
r,g,b=120,120,120
brightness=(r+g+b)//3
print(brightness)

# %%
# Q08. `/`하고 `//`는 뭐가 다르지?
print(7/3, type(7/3))
print(7//3, type(7//3))

# %%
# Q09. 빨간색이 왜 밝기 85지?
for rgb in [(255,0,0),(0,255,0),(0,0,255)]:
    print(rgb, sum(rgb)//3)

# %%
# Q10. 밝기 계산을 함수로 만들 필요가 있나?
def calc_brightness(r,g,b):
    return (r+g+b)//3
print(calc_brightness(255,0,0))

# %%
# Q11. H랑 W는 뭐지?
H=3
W=4
print("H:",H,"W:",W)

# %%
# Q12. 전체 픽셀 수는 왜 H*W지?
H=2
W=5
print(H*W)

# %%
# Q13. `3 3`을 변수 두 개에 어떻게 넣지?
line="3 3"
print(line.split())
h,w=map(int,line.split())
print(h,w,type(h))

# %%
# Q14. 한 줄에 RGB가 여러 개 있으면 어떻게 나누지?
row="255,255,255 200,200,200 0,0,0"
pixels=row.split()
print(pixels)
print(len(pixels))

# %%
# Q15. 픽셀 하나 안의 RGB는 어떻게 나누지?
pixel="255,0,0"
parts=pixel.split(",")
print(parts)
print(len(parts))

# %%
# Q16. 문자열 상태로 숫자를 더하면 왜 안 되지?
a="2"
b="3"
print("문자열:",a+b)
print("정수:",int(a)+int(b))

# %%
# Q17. `map(int, ...)`는 대체 뭐지?
parts="255,0,0".split(",")
print(parts)
r,g,b=map(int,parts)
print(r,g,b,type(r))

# %%
# Q18. for문을 왜 두 번 쓰지?
rows=[[1,2,3],[4,5,6]]
for row in rows:
    print("행:",row)
    for value in row:
        print(" 값:",value)

# %%
# Q19. `brightness_row = []`는 왜 안쪽에서 만들지?
print('행마다 새 리스트를 만들어야 앞 행과 섞이지 않는다.')

# %%
# Q20. append는 여기서 뭘 하는 거지?
values=[]
for x in [255,200,0]:
    values.append(x)
    print(values)

# %%
# Q21. 밝기들을 왜 2차원 리스트로 저장하지?
m=[[255,200,0],[120,60,30]]
print(m)
print(m[1][0])

# %%
# Q22. 합계를 구할 때 왜 total=0부터 시작하지?
total=0
for x in [255,200,0]:
    total += x
    print("현재 합:",total)

# %%
# Q23. `total += brightness`는 무슨 뜻이지?
total=10
brightness=20
total += brightness
print(total)

# %%
# Q24. threshold가 대체 뭐지?
brightness=[255,200,0,120,60,30,85,85,85]
threshold=sum(brightness)//len(brightness)
print(threshold)

# %%
# Q25. 예제 threshold가 왜 102지?
brightness=[255,200,0,120,60,30,85,85,85]
print("합:",sum(brightness))
print("개수:",len(brightness))
print("threshold:",sum(brightness)//len(brightness))

# %%
# Q26. 밝기 합도 for문 두 번으로 구해야 하나?
m=[[255,200,0],[120,60,30]]
total=0
for row in m:
    for x in row:
        total+=x
        print("더한 값:",x,"합:",total)

# %%
# Q27. threshold 계산에 H와 W가 왜 필요하지?
H,W=2,3
print("픽셀 수:",H*W)

# %%
# Q28. 픽셀 수를 len으로 구해도 되나?
m=[[1,2,3],[4,5,6]]
print(len(m)*len(m[0]))
print(2*3)

# %%
# Q29. 왜 threshold부터 출력하지?
threshold=102
result=["110","100","000"]
print(threshold)
for row in result:
    print(row)

# %%
# Q30. 결과를 왜 문자열로 만들지?
values=[1,1,0]
print(values)
print("".join(map(str,values)))

# %%
# Q31. `result_row = ''`도 왜 행마다 새로 만들지?
rows=[[1,1,0],[1,0,0]]
for row in rows:
    result_row=""
    for x in row:
        result_row += str(x)
    print(result_row)

# %%
# Q32. 밝기가 threshold 이상이면 왜 1이지?
threshold=102
for b in [120,85,102]:
    print(b, "->", 1 if b>=threshold else 0)

# %%
# Q33. 왜 `>`가 아니라 `>=`지?
print(100>100)
print(100>=100)

# %%
# Q34. 한 행이 끝난 뒤 result에 append하는 이유는?
result=[]
for row in ["110","100","000"]:
    result.append(row)
    print(result)

# %%
# Q35. 흑백 변환 함수를 따로 만들면 뭐가 좋지?
print('밝기 계산과 비교 작업을 따로 확인할 수 있다.')

# %%
# Q36. main 함수는 왜 쓰지?
def main_test():
    print("입력 -> 계산 -> 출력")
main_test()

# %%
# Q37. `if __name__ == '__main__'`은 뭔데?
print("__name__ =", __name__)
if __name__=="__main__":
    print("직접 실행 상태")

# %%
# Q38. 예제 RGB를 직접 밝기로 바꾸면 뭐가 나오지?
print('255,200,0 / 120,60,30 / 85,85,85가 된다.')

# %%
# Q39. 첫 번째 결과가 왜 110이지?
row=[255,200,0]
t=102
out=""
for b in row:
    out += "1" if b>=t else "0"
    print(b,"->",out[-1])
print(out)

# %%
# Q40. 전부 검은색인데 왜 결과가 1이 될 수 있지?
m=[[0,0],[0,0]]
t=sum(sum(r) for r in m)//4
print("threshold:",t)
print(["".join("1" if b>=t else "0" for b in r) for r in m])

# %%
# Q41. 전부 흰색이면 어떻게 되지?
m=[[255,255],[255,255]]
t=sum(sum(r) for r in m)//4
print("threshold:",t)
print(["".join("1" if b>=t else "0" for b in r) for r in m])

# %%
# Q42. 1x1 이미지는 왜 항상 1이지?
for b in [0,50,128,255]:
    t=b
    print(b, "->", 1 if b>=t else 0)

# %%
# Q43. 입력받으면서 total도 같이 더해도 되나?
print('가능하고 한 번 덜 돌 수 있지만 처음엔 분리하는 게 이해하기 쉽다.')

# %%
# Q44. sum()을 쓰면 더 짧아지나?
m=[[1,2,3],[4,5,6]]
total1=0
for row in m:
    for x in row:
        total1 += x
total2=sum(sum(row) for row in m)
print(total1,total2)

# %%
# Q45. join()을 써도 되나?
row=[120,85,102]
t=102
parts=[]
for b in row:
    parts.append("1" if b>=t else "0")
print(parts)
print("".join(parts))

# %%
# Q46. 변수 이름은 왜 길게 쓰지?
a=920
b=9
threshold=a//b
print(threshold)

# %%
# Q47. 주석은 많이 달수록 좋은가?
# threshold와 같은 값도 1이므로 >= 사용
brightness=102
threshold=102
print(brightness>=threshold)

# %%
# Q48. 함수 하나에 전부 넣으면 안 되나?
def all_in_one(row,t):
    return "".join("1" if x>=t else "0" for x in row)
print(all_in_one([255,200,0],102))

# %%
# Q49. 테스트를 여러 개 해야 하나?
tests=["예제","전체 검정","전체 흰색","1x1","경계값"]
for t in tests:
    print(t)

# %%
# Q50. 예상값과 실제값을 왜 따로 적지?
expected=6
actual=1+2+3
print("expected:",expected)
print("actual:",actual)
print("PASS" if expected==actual else "FAIL")

# %%
# Q51. 시간 복잡도라는 건 여기서 뭘 보지?
for H,W in [(1,1),(10,10),(100,100)]:
    print(H,W,"픽셀:",H*W)

# %%
# Q52. 공간 복잡도는 뭐지?
pixels=100*100
print("밝기 맵 값 개수:",pixels)
print("결과도 대략 같은 개수의 픽셀 정보를 가짐")

# %%
# Q53. H,W가 100이면 얼마나 큰 거지?
H=W=100
print(H*W)

# %%
# Q54. 한 줄에 픽셀 수가 W개인지 확인할 수 있나?
W=3
pixels="255,0,0 0,255,0 0,0,255".split()
print(len(pixels), len(pixels)==W)

# %%
# Q55. RGB가 세 조각인지도 확인할 수 있나?
for p in ["255,0,0","255,0","1,2,3,4"]:
    parts=p.split(",")
    print(p,parts,len(parts)==3)

# %%
# Q56. RGB 값이 0~255인지 검사할 수 있나?
for rgb in [(255,0,0),(300,0,0),(-1,10,20)]:
    ok=all(0<=v<=255 for v in rgb)
    print(rgb,ok)

# %%
# Q57. 실제 사진 밝기 공식도 똑같나?
r,g,b=255,0,0
simple=(r+g+b)//3
weighted=int(0.299*r+0.587*g+0.114*b)
print("과제 공식:",simple)
print("다른 공식 예:",weighted)

# %%
# Q58. 평균 말고 중앙값을 써도 되나?
values=[0,0,0,0,255]
avg=sum(values)//len(values)
median=sorted(values)[len(values)//2]
print("평균:",avg,"중앙값:",median)

# %%
# Q59. threshold가 0도 될 수 있나?
values=[0,0,0,0]
t=sum(values)//len(values)
print(t)

# %%
# Q60. threshold가 255도 될 수 있나?
values=[255,255,255,255]
t=sum(values)//len(values)
print(t)

# %%
# Q61. threshold와 딱 같은 값은 0일까 1일까?
t=100
for b in [99,100,101]:
    print(b, b>=t)

# %%
# Q62. 결과 한 줄 길이는 왜 W와 같아야 하지?
W=3
row=[255,200,0]
out="".join("1" if b>=102 else "0" for b in row)
print(out,len(out),len(out)==W)

# %%
# Q63. 결과 줄 수는 왜 H와 같아야 하지?
H=3
m=[[1,2],[3,4],[5,6]]
out=["11","11","11"]
print(len(out),len(out)==H)

# %%
# Q64. 출력에 공백 넣으면 왜 안 되지?
print(1,1,0)
print(1,1,0,sep="")
print("110")

# %%
# Q65. 노트북에서는 왜 input을 안 쓰는 게 편하지?
row_text="255,255,255 200,200,200 0,0,0"
pixels=row_text.split()
print(pixels)

# %%
# Q66. 노트북 셀을 따로 실행해도 되게 만들 수 있나?
x=60
print("이 셀 안에서 만든 값:",x)

# %%
# Q67. ipynb가 실행 안 되면 뭘 먼저 봐야 하지?
import sys
print(sys.executable)
print(sys.version.split()[0])

# %%
# Q68. 가상환경은 왜 쓰지?
import sys
print("현재 Python:",sys.executable)
print("가상환경을 쓴다면 경로에 .venv가 보이는지 확인")

# %%
# Q69. 파일 경로 오류는 왜 자꾸 나지?
import os
print(os.getcwd())

# %%
# Q70. 오류 메시지는 어디부터 보면 되지?
try:
    int("abc")
except Exception as e:
    print(type(e).__name__)
    print(e)

# %%
# Q71. AI한테 오류를 물어볼 때 뭘 같이 보내야 하지?
question_info=["오류 메시지","관련 코드","사용한 입력","기대한 결과","실제 결과"]
for x in question_info:
    print("-",x)

# %%
# Q72. AI 답변이 맞는지 어떻게 확인하지?
print('작은 값과 경계값을 직접 계산하고 코드 결과와 비교한다.')

# %%
# Q73. assert는 뭐에 쓰지?
def brightness(r,g,b):
    return (r+g+b)//3
assert brightness(0,0,0)==0
assert brightness(255,255,255)==255
assert brightness(255,0,0)==85
print("assert 통과")

# %%
# Q74. 최종 코드와 연습 코드는 어떻게 나눌까?
files={"problem02.py":"최종 코드","problem02_learning.ipynb":"연습/실험","AI_LOG.md":"AI 질문 요약"}
for name,role in files.items():
    print(name,":",role)

# %%
# Q75. 이제 처음부터 다시 풀면 어떤 순서로 해야 하지?
steps=["입력","RGB 분리","밝기 계산","평균 threshold","0/1 변환","출력","테스트"]
for i,step in enumerate(steps,1):
    print(i,step)
